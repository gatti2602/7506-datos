# %%
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
events = pd.read_csv('../data/installs.csv.gzip',compression='gzip', dtype='object')
events.describe().transpose()
# Out:
#                    count unique  \
# created             3412   3412
# application_id      3412     31
# ref_type            3412      2
# ref_hash            3412   3008
# click_hash             0      0
# attributed          3412      1
# implicit            3412      2
# device_countrycode  3412      2
# device_brand        1047     27
# device_model        3411    415
# session_user_agent  3364     12
# user_agent          1729    334
# event_uuid           865    865
# kind                 865     20
# wifi                1729      2
# trans_id               6      4
# ip_address          3412   2717
# device_language     3378     30
#
#                                                                  top  freq
# created                                      2019-03-12 16:40:43.679     1
# application_id                                                     7   947
# ref_type                                         1891515180541284343  2080
# ...
