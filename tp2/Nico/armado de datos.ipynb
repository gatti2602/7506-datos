# %%
import pandas as pd
# Out:
# c:\users\lt5420\appdata\local\programs\python\python37\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %%
auctions = pd.read_csv('../data/auctions.csv.gzip', compression='gzip', dtype='object', parse_dates=['date'])

# %%
auctions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47409528 entries, 0 to 47409527
# Data columns (total 4 columns):
# date           datetime64[ns]
# device_id      object
# ref_type_id    object
# source_id      object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 1.4+ GB

# %%
auctions.head()
# Out:
#                         date            device_id ref_type_id source_id
# 0 2019-04-23 18:58:00.842116  2564673204772915246           1         0
# 1 2019-04-23 18:58:01.530771  4441121667607578179           7         0
# 2 2019-04-23 18:58:01.767562  7721769811471055264           1         0
# 3 2019-04-23 18:58:02.363468  6416039086842158968           1         0
# 4 2019-04-23 18:58:02.397559  1258642015983312729           1         0

# %%
installs = pd.read_csv('../data/installs.csv.gzip', compression='gzip')
# Out:
# c:\users\lt5420\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (4,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
installs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481511 entries, 0 to 481510
# Data columns (total 18 columns):
# created               481511 non-null object
# application_id        481511 non-null int64
# ref_type              481511 non-null int64
# ref_hash              481511 non-null int64
# click_hash            1142 non-null object
# attributed            481511 non-null bool
# implicit              481511 non-null bool
# device_countrycode    481511 non-null int64
# device_brand          276443 non-null float64
# device_model          454619 non-null float64
# session_user_agent    466672 non-null object
# user_agent            330768 non-null object
# event_uuid            103168 non-null object
# kind                  103168 non-null object
# wifi                  294829 non-null object
# trans_id              8933 non-null object
# ip_address            481511 non-null int64
# device_language       453934 non-null float64
# ...

# %%
installs.head()
# Out:
#                    created  application_id             ref_type  \
# 0  2019-04-24 06:23:29.495               1  1494519392962156891
# 1  2019-04-24 02:06:01.032               1  1494519392962156891
# 2  2019-04-20 10:15:36.274               1  1494519392962156891
# 3  2019-04-20 21:56:47.151               1  1494519392962156891
# 4  2019-04-20 22:40:41.239               1  1494519392962156891
#
#               ref_hash click_hash  attributed  implicit   device_countrycode  \
# 0  4716708407362582887        NaN       False      True  6287817205707153877
# 1  7143568733100935872        NaN       False     False  6287817205707153877
# 2  5230323462636548010        NaN       False      True  6287817205707153877
# 3  5097163995161606833        NaN       False      True  6287817205707153877
# 4  6328027616411983332        NaN       False     False  6287817205707153877
#
#    device_brand  device_model session_user_agent user_agent  \
# ...

# %%
clicks = pd.read_csv('../data/clicks.csv.gzip', compression='gzip')
# Out:
# c:\users\lt5420\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
clicks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64296 entries, 0 to 64295
# Data columns (total 20 columns):
# advertiser_id      64296 non-null int64
# action_id          7 non-null float64
# source_id          64296 non-null int64
# created            64296 non-null object
# country_code       64296 non-null int64
# latitude           64296 non-null float64
# longitude          64296 non-null float64
# wifi_connection    64296 non-null bool
# carrier_id         63097 non-null float64
# trans_id           64296 non-null object
# os_minor           64261 non-null float64
# agent_device       8920 non-null float64
# os_major           64261 non-null float64
# specs_brand        64296 non-null int64
# brand              15035 non-null float64
# timeToClick        38178 non-null float64
# touchX             43678 non-null object
# touchY             43678 non-null object
# ref_type           64296 non-null int64
# ref_hash           64296 non-null int64
# ...

# %%
clicks.head().transpose()
# Out:
#                                                0  \
# advertiser_id                                  1
# action_id                                    NaN
# source_id                                      2
# created                 2019-04-18T05:27:42.197Z
# country_code                 6287817205707153877
# latitude                                 1.71455
# longitude                               0.871535
# wifi_connection                            False
# carrier_id                                     3
# trans_id         9JMAfrb-b9cSEVCJb0P9JfihGthaS7E
# os_minor                             1.51764e+18
# agent_device                                 NaN
# os_major                             5.13162e+18
# specs_brand                    71913840936116953
# brand                                          0
# timeToClick                                2.317
# touchX                                     0.968
# touchY                                     0.503
# ...

# %%
events = pd.read_csv('../data/events.csv.gzip', compression='gzip')
# Out:
# c:\users\lt5420\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (13,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7744581 entries, 0 to 7744580
# Data columns (total 23 columns):
# index                 int64
# date                  object
# event_id              int64
# ref_type              int64
# ref_hash              int64
# application_id        int64
# attributed            bool
# device_countrycode    int64
# device_os_version     float64
# device_brand          float64
# device_model          float64
# device_city           float64
# session_user_agent    float64
# trans_id              object
# user_agent            float64
# event_uuid            object
# carrier               float64
# kind                  float64
# device_os             float64
# wifi                  bool
# connection_type       object
# ip_address            int64
# device_language       float64
# dtypes: bool(2), float64(10), int64(7), object(4)
# memory usage: 1.2+ GB

# %%
events.head().transpose()
# Out:
#                                                        0  \
# index                                            2130678
# date                             2019-04-20 01:42:49.120
# event_id                                               0
# ref_type                             1891515180541284343
# ref_hash                             5857744372586891366
# application_id                                       210
# attributed                                         False
# device_countrycode                   6287817205707153877
# device_os_version                                    NaN
# device_brand                                         NaN
# device_model                                 4.31829e+18
# device_city                                          NaN
# session_user_agent                           3.81952e+18
# trans_id                                             NaN
# user_agent                                   5.04619e+18
# ...
